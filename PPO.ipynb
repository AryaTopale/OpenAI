# %% [markdown]
# ##Libraries

# %%
import os
import numpy as np
import torch as T
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical

# %% [markdown]
# ##Initializing PPOMemory

# %%
class PPOMemory:
    def __init__(self, batch_size):
        self.states = []
        self.probs = []
        self.values = []
        self.actions = []
        self.rewards = []
        self.done = []
        self.batch_size = batch_size

    def generate_batches(self):
        n_states = len(self.states)
        batch_start = np.arange(0, n_states, self.batch_size)
        indices = np.arange(n_states, dtype=np.int64)
        np.random.shuffle(indices)
        batches = [indices[i:i + self.batch_size] for i in batch_start]
        return np.array(self.states), np.array(self.actions), np.array(self.probs), np.array(self.values), np.array(self.rewards), np.array(self.done), batches

    def store_memory(self, state, action, reward, value, prob, done):
        self.states.append(state)
        self.actions.append(action)
        self.rewards.append(reward)
        self.values.append(value)
        self.probs.append(prob)
        self.done.append(done)

    def clear_memory(self):
        self.states = []
        self.probs = []
        self.values = []
        self.actions = []
        self.rewards = []
        self.done = []

# %% [markdown]
# ##Actor Network

# %%
class ActorNetwork(nn.Module):
    def __init__(self, n_actions, input_dims, alpha, fc1_dims=256, fc2_dims=256):
        super(ActorNetwork, self).__init__()
        self.actor = nn.Sequential(
            nn.Linear(*input_dims, fc1_dims),
            nn.ReLU(),
            nn.Linear(fc1_dims, fc2_dims),
            nn.ReLU(),
            nn.Linear(fc2_dims, n_actions),
            nn.Softmax(dim=-1)
        )
        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        dist = self.actor(state)
        dist = Categorical(dist)
        return dist

    def save_checkpoint(self, filename='actor_torch_ppo'):
        T.save(self.state_dict(), filename)

# %% [markdown]
# ##Critic Network

# %%
class CriticNetwork(nn.Module):
    def __init__(self, input_dims, alpha, fc1_dims=256, fc2_dims=256):
        super(CriticNetwork, self).__init__()
        self.critic = nn.Sequential(
            nn.Linear(*input_dims, fc1_dims),
            nn.ReLU(),
            nn.Linear(fc1_dims, fc2_dims),
            nn.ReLU(),
            nn.Linear(fc2_dims, 1)
        )
        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        value = self.critic(state)
        return value

    def save_checkpoint(self, filename='critic_torch_ppo'):
        T.save(self.state_dict(), filename)

    def load_checkpoint(self, filename='critic_torch_ppo'):
        self.load_state_dict(T.load(filename))

# %% [markdown]
# ##Agent Class

# %%
class Agent:
    def __init__(self, n_actions, input_dims, gamma=0.99, alpha=0.0003, gae_lambda=0.95, policy_clip=0.1, batch_size=64, N=2048, n_epochs=10):
        self.gamma = gamma
        self.policy_clip = policy_clip
        self.n_epochs = n_epochs
        self.gae_lambda = gae_lambda
        self.actor = ActorNetwork(n_actions, input_dims, alpha)
        self.critic = CriticNetwork(input_dims, alpha)
        self.memory = PPOMemory(batch_size)

    def remember(self, state, action, probs, vals, reward, done):
        self.memory.store_memory(state, action, probs, vals, reward, done)

    def save_models(self):
        print('..saving models...')
        self.actor.save_checkpoint()
        self.critic.save_checkpoint()

    def load_models(self):
        print('..loading models...')
        self.actor.load_checkpoint()
        self.critic.load_checkpoint()

    def choose_action(self, observation):
        state = T.tensor(observation, dtype=T.float).to(self.actor.device)
        dist = self.actor(state)
        value = self.critic(state)
        action = dist.sample()
        probs = T.squeeze(dist.log_prob(action)).item()
        action = T.squeeze(action).item()
        value = T.squeeze(value).item()
        return action, probs, value

    def learn(self):
        for _ in range(self.n_epochs):
            state_arr, action_arr, old_probs_arr, vals_arr, reward_arr, done_arr, batches = self.memory.generate_batches()
            values = vals_arr
            advantage = np.zeros(len(reward_arr), dtype=np.float32)
            for t in range(len(reward_arr) - 1):
                discount = 1
                a_t = 0
                for k in range(t, len(reward_arr) - 1):
                    a_t += discount * (reward_arr[k] + self.gamma * values[k + 1] * (1 - int(done_arr[k])) - values[k])
                    discount *= self.gamma * self.gae_lambda
                advantage[t] = a_t
            advantage = T.tensor(advantage).to(self.actor.device)
            values = T.tensor(values).to(self.actor.device)
            for batch in batches:
                states = T.tensor(state_arr[batch], dtype=T.float).to(self.actor.device)
                old_probs = T.tensor(old_probs_arr[batch]).to(self.actor.device)
                actions = T.tensor(action_arr[batch]).to(self.actor.device)
                dist = self.actor(states)
                critic_value = self.critic(states)
                critic_value = T.squeeze(critic_value)
                new_probs = dist.log_prob(actions)
                prob_ratio = new_probs.exp() / old_probs.exp()
                weighted_probs = advantage[batch] * prob_ratio
                weighted_clipped_probs = T.clamp(prob_ratio, 1 - self.policy_clip, 1 + self.policy_clip) * advantage[batch]
                actor_loss = -T.min(weighted_probs, weighted_clipped_probs).mean()
                returns = advantage[batch] + values[batch]
                critic_loss = (returns - critic_value) ** 2
                critic_loss = critic_loss.mean()
                total_loss = actor_loss + 0.5 * critic_loss
                self.actor.optimizer.zero_grad()
                self.critic.optimizer.zero_grad()
                total_loss.backward()
                self.actor.optimizer.step()
                self.critic.optimizer.step()
        self.memory.clear_memory()

# %% [markdown]
# ##Training

# %%
def train_agent(env, agent, n_games):
    best_score = env.reward_range[0]
    score_history = []

    for i in range(n_games):
        observation = env.reset()
        done = False
        score = 0
        while not done:
            action, prob, val = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            agent.remember(observation, action, prob, val, reward, done)
            score += reward
            observation = observation_
        agent.learn()
        score_history.append(score)
        avg_score = np.mean(score_history[-100:])

        if avg_score > best_score:
            best_score = avg_score
            agent.save_models()

        print(f'episode {i}, score {score}, avg score {avg_score}')
        env.render()

# %%
import gym
import numpy as np

# %%
if __name__ == '__main__':
    env = gym.make('CartPole-v1')
    n_actions = env.action_space.n
    input_dims = env.observation_space.shape
    agent = Agent(n_actions=n_actions, input_dims=input_dims)
    n_games = 1000
    train_agent(env, agent, n_games)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# /usr/local/lib/python3.10/dist-packages/gym/core.py:49: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# ..saving models...
# episode 0, score 17.0, avg score 17.0
# episode 1, score 15.0, avg score 16.0
# episode 2, score 15.0, avg score 15.666666666666666
# ..saving models...
# episode 3, score 28.0, avg score 18.75
# episode 4, score 16.0, avg score 18.2
# ..saving models...
# episode 5, score 32.0, avg score 20.5
# episode 6, score 12.0, avg score 19.285714285714285
# episode 7, score 25.0, avg score 20.0
# ..saving models...
# episode 8, score 35.0, avg score 21.666666666666668
# episode 9, score 12.0, avg score 20.7
# episode 10, score 21.0, avg score 20.727272727272727
# episode 11, score 10.0, avg score 19.833333333333332
# episode 12, score 41.0, avg score 21.46153846153846
# episode 13, score 15.0, avg score 21.0
# episode 14, score 9.0, avg score 20.2
# episode 15, score 12.0, avg score 19.6875
# episode 16, score 10.0, avg score 19.11764705882353
# episode 17, score 32.0, avg score 19.833333333333332
# episode 18, score 33.0, avg score 20.526315789473685
# ..saving models...
# episode 19, score 171.0, avg score 28.05
# ..saving models...
# episode 20, score 63.0, avg score 29.714285714285715
# ..saving models...
# episode 21, score 54.0, avg score 30.818181818181817
# ..saving models...
# episode 22, score 39.0, avg score 31.17391304347826
# ..saving models...
# episode 23, score 44.0, avg score 31.708333333333332
# ..saving models...
# episode 24, score 43.0, avg score 32.16
# ..saving models...
# episode 25, score 62.0, avg score 33.30769230769231
# ..saving models...
# episode 26, score 43.0, avg score 33.666666666666664
# ..saving models...
# episode 27, score 35.0, avg score 33.714285714285715
# ..saving models...
# episode 28, score 40.0, avg score 33.93103448275862
# ..saving models...
# episode 29, score 79.0, avg score 35.43333333333333
# ..saving models...
# episode 30, score 74.0, avg score 36.67741935483871
# ..saving models...
# episode 31, score 90.0, avg score 38.34375
# ..saving models...
# episode 32, score 41.0, avg score 38.42424242424242
# episode 33, score 34.0, avg score 38.294117647058826
# ..saving models...
# episode 34, score 52.0, avg score 38.68571428571428
# ..saving models...
# episode 35, score 64.0, avg score 39.388888888888886
# ..saving models...
# episode 36, score 46.0, avg score 39.567567567567565
# ..saving models...
# episode 37, score 55.0, avg score 39.973684210526315
# episode 38, score 33.0, avg score 39.794871794871796
# ..saving models...
# episode 39, score 112.0, avg score 41.6
# episode 40, score 39.0, avg score 41.53658536585366
# ..saving models...
# episode 41, score 154.0, avg score 44.214285714285715
# ..saving models...
# episode 42, score 59.0, avg score 44.55813953488372
# episode 43, score 32.0, avg score 44.27272727272727
# episode 44, score 42.0, avg score 44.22222222222222
# ..saving models...
# episode 45, score 104.0, avg score 45.52173913043478
# ..saving models...
# episode 46, score 51.0, avg score 45.638297872340424
# ..saving models...
# episode 47, score 53.0, avg score 45.791666666666664
# ..saving models...
# episode 48, score 55.0, avg score 45.97959183673469
# episode 49, score 39.0, avg score 45.84
# episode 50, score 35.0, avg score 45.627450980392155
# episode 51, score 30.0, avg score 45.32692307692308
# episode 52, score 63.0, avg score 45.660377358490564
# episode 53, score 59.0, avg score 45.907407407407405
# episode 54, score 40.0, avg score 45.8
# episode 55, score 52.0, avg score 45.910714285714285
# ..saving models...
# episode 56, score 55.0, avg score 46.07017543859649
# ..saving models...
# episode 57, score 178.0, avg score 48.3448275862069
# episode 58, score 41.0, avg score 48.220338983050844
# ..saving models...
# episode 59, score 74.0, avg score 48.65
# ..saving models...
# episode 60, score 208.0, avg score 51.26229508196721
# episode 61, score 51.0, avg score 51.25806451612903
# ..saving models...
# episode 62, score 87.0, avg score 51.82539682539682
# episode 63, score 45.0, avg score 51.71875
# ..saving models...
# episode 64, score 79.0, avg score 52.13846153846154
# episode 65, score 42.0, avg score 51.984848484848484
# episode 66, score 39.0, avg score 51.791044776119406
# episode 67, score 37.0, avg score 51.5735294117647
# episode 68, score 48.0, avg score 51.52173913043478
# episode 69, score 41.0, avg score 51.371428571428574
# episode 70, score 35.0, avg score 51.140845070422536
# episode 71, score 39.0, avg score 50.97222222222222
# episode 72, score 35.0, avg score 50.75342465753425
# episode 73, score 48.0, avg score 50.71621621621622
# episode 74, score 43.0, avg score 50.61333333333334
# episode 75, score 41.0, avg score 50.48684210526316
# episode 76, score 50.0, avg score 50.48051948051948
# episode 77, score 148.0, avg score 51.73076923076923
# episode 78, score 39.0, avg score 51.56962025316456
# episode 79, score 51.0, avg score 51.5625
# ..saving models...
# episode 80, score 105.0, avg score 52.22222222222222
# episode 81, score 50.0, avg score 52.19512195121951
# ..saving models...
# episode 82, score 55.0, avg score 52.2289156626506
# episode 83, score 37.0, avg score 52.04761904761905
# episode 84, score 45.0, avg score 51.96470588235294
# ..saving models...
# episode 85, score 92.0, avg score 52.43023255813954
# episode 86, score 48.0, avg score 52.37931034482759
# episode 87, score 42.0, avg score 52.26136363636363
# ..saving models...
# episode 88, score 111.0, avg score 52.92134831460674
# episode 89, score 50.0, avg score 52.888888888888886
# episode 90, score 51.0, avg score 52.86813186813187
# ..saving models...
# episode 91, score 61.0, avg score 52.95652173913044
# episode 92, score 51.0, avg score 52.935483870967744
# ..saving models...
# episode 93, score 119.0, avg score 53.638297872340424
# episode 94, score 52.0, avg score 53.62105263157895
# ..saving models...
# episode 95, score 74.0, avg score 53.833333333333336
# ..saving models...
# episode 96, score 74.0, avg score 54.04123711340206
# episode 97, score 39.0, avg score 53.88775510204081
# episode 98, score 39.0, avg score 53.73737373737374
# episode 99, score 43.0, avg score 53.63
# episode 100, score 47.0, avg score 53.93
# ..saving models...
# episode 101, score 50.0, avg score 54.28
# ..saving models...
# episode 102, score 220.0, avg score 56.33
# ..saving models...
# episode 103, score 88.0, avg score 56.93
# ..saving models...
# episode 104, score 46.0, avg score 57.23
# ..saving models...
# episode 105, score 72.0, avg score 57.63
# ..saving models...
# episode 106, score 68.0, avg score 58.19
# ..saving models...
# episode 107, score 62.0, avg score 58.56
# ..saving models...
# episode 108, score 44.0, avg score 58.65
# ..saving models...
# episode 109, score 86.0, avg score 59.39
# ..saving models...
# episode 110, score 38.0, avg score 59.56
# ..saving models...
# episode 111, score 75.0, avg score 60.21
# ..saving models...
# episode 112, score 57.0, avg score 60.37
# ..saving models...
# episode 113, score 44.0, avg score 60.66
# ..saving models...
# episode 114, score 69.0, avg score 61.26
# ..saving models...
# episode 115, score 62.0, avg score 61.76
# ..saving models...
# episode 116, score 50.0, avg score 62.16
# ..saving models...
# episode 117, score 94.0, avg score 62.78
# ..saving models...
# episode 118, score 51.0, avg score 62.96
# episode 119, score 95.0, avg score 62.2
# episode 120, score 75.0, avg score 62.32
# episode 121, score 78.0, avg score 62.56
# episode 122, score 53.0, avg score 62.7
# ..saving models...
# episode 123, score 78.0, avg score 63.04
# ..saving models...
# episode 124, score 47.0, avg score 63.08
# ..saving models...
# episode 125, score 74.0, avg score 63.2
# ..saving models...
# episode 126, score 114.0, avg score 63.91
# ..saving models...
# episode 127, score 95.0, avg score 64.51
# ..saving models...
# episode 128, score 70.0, avg score 64.81
# episode 129, score 48.0, avg score 64.5
# episode 130, score 67.0, avg score 64.43
# episode 131, score 128.0, avg score 64.81
# ..saving models...
# episode 132, score 105.0, avg score 65.45
# ..saving models...
# episode 133, score 227.0, avg score 67.38
# ..saving models...
# episode 134, score 177.0, avg score 68.63
# episode 135, score 56.0, avg score 68.55
# ..saving models...
# episode 136, score 127.0, avg score 69.36
# ..saving models...
# episode 137, score 423.0, avg score 73.04
# ..saving models...
# episode 138, score 418.0, avg score 76.89
# episode 139, score 109.0, avg score 76.86
# ..saving models...
# episode 140, score 93.0, avg score 77.4
# episode 141, score 78.0, avg score 76.64
# episode 142, score 59.0, avg score 76.64
# episode 143, score 67.0, avg score 76.99
# ..saving models...
# episode 144, score 96.0, avg score 77.53
# ..saving models...
# episode 145, score 107.0, avg score 77.56
# ..saving models...
# episode 146, score 77.0, avg score 77.82
# ..saving models...
# episode 147, score 81.0, avg score 78.1
# ..saving models...
# episode 148, score 200.0, avg score 79.55
# ..saving models...
# episode 149, score 89.0, avg score 80.05
# ..saving models...
# episode 150, score 118.0, avg score 80.88
# ..saving models...
# episode 151, score 77.0, avg score 81.35
# ..saving models...
# episode 152, score 148.0, avg score 82.2
# ..saving models...
# episode 153, score 100.0, avg score 82.61
# ..saving models...
# episode 154, score 270.0, avg score 84.91
# ..saving models...
# episode 155, score 80.0, avg score 85.19
# ..saving models...
# episode 156, score 73.0, avg score 85.37
# episode 157, score 93.0, avg score 84.52
# episode 158, score 74.0, avg score 84.85
# episode 159, score 89.0, avg score 85.0
# episode 160, score 123.0, avg score 84.15
# episode 161, score 80.0, avg score 84.44
# ..saving models...
# episode 162, score 215.0, avg score 85.72
# ..saving models...
# episode 163, score 75.0, avg score 86.02
# ..saving models...
# episode 164, score 101.0, avg score 86.24
# ..saving models...
# episode 165, score 81.0, avg score 86.63
# ..saving models...
# episode 166, score 78.0, avg score 87.02
# ..saving models...
# episode 167, score 88.0, avg score 87.53
# ..saving models...
# episode 168, score 131.0, avg score 88.36
# ..saving models...
# episode 169, score 99.0, avg score 88.94
# ..saving models...
# episode 170, score 116.0, avg score 89.75
# ..saving models...
# episode 171, score 73.0, avg score 90.09
# ..saving models...
# episode 172, score 63.0, avg score 90.37
# ..saving models...
# episode 173, score 81.0, avg score 90.7
# ..saving models...
# episode 174, score 65.0, avg score 90.92
# ..saving models...
# episode 175, score 77.0, avg score 91.28
# ..saving models...
# episode 176, score 53.0, avg score 91.31
# episode 177, score 54.0, avg score 90.37
# ..saving models...
# episode 178, score 215.0, avg score 92.13
# ..saving models...
# episode 179, score 262.0, avg score 94.24
# episode 180, score 84.0, avg score 94.03
# ..saving models...
# episode 181, score 112.0, avg score 94.65
# ..saving models...
# episode 182, score 70.0, avg score 94.8
# ..saving models...
# episode 183, score 83.0, avg score 95.26
# ..saving models...
# episode 184, score 104.0, avg score 95.85
# ..saving models...
# episode 185, score 115.0, avg score 96.08
# ..saving models...
# episode 186, score 193.0, avg score 97.53
# ..saving models...
# episode 187, score 201.0, avg score 99.12
# ..saving models...
# episode 188, score 122.0, avg score 99.23
# ..saving models...
# episode 189, score 80.0, avg score 99.53
# ..saving models...
# episode 190, score 78.0, avg score 99.8
# ..saving models...
# episode 191, score 235.0, avg score 101.54
# ..saving models...
# episode 192, score 196.0, avg score 102.99
# episode 193, score 75.0, avg score 102.55
# episode 194, score 78.0, avg score 102.81
# ..saving models...
# episode 195, score 104.0, avg score 103.11
# ..saving models...
# episode 196, score 217.0, avg score 104.54
# ..saving models...
# episode 197, score 266.0, avg score 106.81
# ..saving models...
# episode 198, score 89.0, avg score 107.31
# ..saving models...
# episode 199, score 140.0, avg score 108.28
# ..saving models...
# episode 200, score 110.0, avg score 108.91
# ..saving models...
# episode 201, score 90.0, avg score 109.31
# episode 202, score 60.0, avg score 107.71
# episode 203, score 97.0, avg score 107.8
# episode 204, score 54.0, avg score 107.88
# episode 205, score 90.0, avg score 108.06
# episode 206, score 80.0, avg score 108.18
# episode 207, score 86.0, avg score 108.42
# episode 208, score 64.0, avg score 108.62
# episode 209, score 82.0, avg score 108.58
# episode 210, score 109.0, avg score 109.29
# episode 211, score 61.0, avg score 109.15
# ..saving models...
# episode 212, score 90.0, avg score 109.48
# ..saving models...
# episode 213, score 72.0, avg score 109.76
# ..saving models...
# episode 214, score 90.0, avg score 109.97
# ..saving models...
# episode 215, score 139.0, avg score 110.74
# ..saving models...
# episode 216, score 89.0, avg score 111.13
# ..saving models...
# episode 217, score 202.0, avg score 112.21
# ..saving models...
# episode 218, score 254.0, avg score 114.24
# ..saving models...
# episode 219, score 161.0, avg score 114.9
# ..saving models...
# episode 220, score 248.0, avg score 116.63
# ..saving models...
# episode 221, score 135.0, avg score 117.2
# ..saving models...
# episode 222, score 91.0, avg score 117.58
# ..saving models...
# episode 223, score 183.0, avg score 118.63
# ..saving models...
# episode 224, score 79.0, avg score 118.95
# episode 225, score 54.0, avg score 118.75
# episode 226, score 105.0, avg score 118.66
# episode 227, score 69.0, avg score 118.4
# episode 228, score 80.0, avg score 118.5
# episode 229, score 67.0, avg score 118.69
# ..saving models...
# episode 230, score 249.0, avg score 120.51
# episode 231, score 87.0, avg score 120.1
# ..saving models...
# episode 232, score 160.0, avg score 120.65
# episode 233, score 88.0, avg score 119.26
# episode 234, score 152.0, avg score 119.01
# ..saving models...
# episode 235, score 307.0, avg score 121.52
# episode 236, score 66.0, avg score 120.91
# episode 237, score 61.0, avg score 117.29
# episode 238, score 167.0, avg score 114.78
# episode 239, score 77.0, avg score 114.46
# episode 240, score 69.0, avg score 114.22
# episode 241, score 87.0, avg score 114.31
# episode 242, score 79.0, avg score 114.51
# episode 243, score 228.0, avg score 116.12
# episode 244, score 143.0, avg score 116.59
# episode 245, score 79.0, avg score 116.31
# episode 246, score 75.0, avg score 116.29
# episode 247, score 49.0, avg score 115.97
# episode 248, score 71.0, avg score 114.68
# episode 249, score 147.0, avg score 115.26
# episode 250, score 76.0, avg score 114.84
# episode 251, score 71.0, avg score 114.78
# episode 252, score 155.0, avg score 114.85
# episode 253, score 67.0, avg score 114.52
# episode 254, score 76.0, avg score 112.58
# episode 255, score 75.0, avg score 112.53
# episode 256, score 149.0, avg score 113.29
# episode 257, score 146.0, avg score 113.82
# episode 258, score 64.0, avg score 113.72
# episode 259, score 82.0, avg score 113.65
# episode 260, score 75.0, avg score 113.17
# episode 261, score 90.0, avg score 113.27
# episode 262, score 86.0, avg score 111.98
# episode 263, score 86.0, avg score 112.09
# episode 264, score 141.0, avg score 112.49
# episode 265, score 163.0, avg score 113.31
# episode 266, score 92.0, avg score 113.45
# episode 267, score 79.0, avg score 113.36
# episode 268, score 63.0, avg score 112.68
# episode 269, score 126.0, avg score 112.95
# episode 270, score 56.0, avg score 112.35
# episode 271, score 74.0, avg score 112.36
# episode 272, score 103.0, avg score 112.76
# episode 273, score 100.0, avg score 112.95
# episode 274, score 78.0, avg score 113.08
# episode 275, score 120.0, avg score 113.51
# episode 276, score 52.0, avg score 113.5
# episode 277, score 100.0, avg score 113.96
# episode 278, score 109.0, avg score 112.9
# episode 279, score 66.0, avg score 110.94
# episode 280, score 56.0, avg score 110.66
# episode 281, score 98.0, avg score 110.52
# episode 282, score 53.0, avg score 110.35
# episode 283, score 99.0, avg score 110.51
# episode 284, score 160.0, avg score 111.07
# episode 285, score 80.0, avg score 110.72
# episode 286, score 78.0, avg score 109.57
# episode 287, score 82.0, avg score 108.38
# episode 288, score 82.0, avg score 107.98
# episode 289, score 97.0, avg score 108.15
# episode 290, score 90.0, avg score 108.27
# episode 291, score 167.0, avg score 107.59
# episode 292, score 126.0, avg score 106.89
# episode 293, score 152.0, avg score 107.66
# episode 294, score 123.0, avg score 108.11
# episode 295, score 242.0, avg score 109.49
# episode 296, score 122.0, avg score 108.54
# episode 297, score 169.0, avg score 107.57
# episode 298, score 56.0, avg score 107.24
# episode 299, score 167.0, avg score 107.51
# episode 300, score 71.0, avg score 107.12
# episode 301, score 143.0, avg score 107.65
# episode 302, score 96.0, avg score 108.01
# episode 303, score 62.0, avg score 107.66
# episode 304, score 84.0, avg score 107.96
# episode 305, score 118.0, avg score 108.24
# episode 306, score 84.0, avg score 108.28
# episode 307, score 84.0, avg score 108.26
# episode 308, score 117.0, avg score 108.79
# episode 309, score 139.0, avg score 109.36
# episode 310, score 92.0, avg score 109.19
# episode 311, score 48.0, avg score 109.06
# episode 312, score 82.0, avg score 108.98
# episode 313, score 146.0, avg score 109.72
# episode 314, score 62.0, avg score 109.44
# episode 315, score 71.0, avg score 108.76
# episode 316, score 52.0, avg score 108.39
# episode 317, score 63.0, avg score 107.0
# episode 318, score 101.0, avg score 105.47
# episode 319, score 80.0, avg score 104.66
# episode 320, score 67.0, avg score 102.85
# episode 321, score 102.0, avg score 102.52
# episode 322, score 203.0, avg score 103.64
# episode 323, score 72.0, avg score 102.53
# episode 324, score 45.0, avg score 102.19
# episode 325, score 73.0, avg score 102.38
# episode 326, score 83.0, avg score 102.16
# episode 327, score 50.0, avg score 101.97
# episode 328, score 89.0, avg score 102.06
# episode 329, score 89.0, avg score 102.28
# episode 330, score 99.0, avg score 100.78
# episode 331, score 50.0, avg score 100.41
# episode 332, score 130.0, avg score 100.11
# episode 333, score 185.0, avg score 101.08
# episode 334, score 83.0, avg score 100.39
# episode 335, score 69.0, avg score 98.01
# episode 336, score 91.0, avg score 98.26
# episode 337, score 85.0, avg score 98.5
# episode 338, score 83.0, avg score 97.66
# episode 339, score 87.0, avg score 97.76
# episode 340, score 84.0, avg score 97.91
# episode 341, score 213.0, avg score 99.17
# episode 342, score 81.0, avg score 99.19
# episode 343, score 78.0, avg score 97.69
# episode 344, score 66.0, avg score 96.92
# episode 345, score 121.0, avg score 97.34
# episode 346, score 50.0, avg score 97.09
# episode 347, score 61.0, avg score 97.21
# episode 348, score 64.0, avg score 97.14
# episode 349, score 74.0, avg score 96.41
# episode 350, score 74.0, avg score 96.39
# episode 351, score 103.0, avg score 96.71
# episode 352, score 110.0, avg score 96.26
# episode 353, score 104.0, avg score 96.63
# episode 354, score 85.0, avg score 96.72
# episode 355, score 110.0, avg score 97.07
# episode 356, score 83.0, avg score 96.41
# episode 357, score 151.0, avg score 96.46
# episode 358, score 153.0, avg score 97.35
# episode 359, score 52.0, avg score 97.05
# episode 360, score 62.0, avg score 96.92
# episode 361, score 111.0, avg score 97.13
# episode 362, score 91.0, avg score 97.18
# episode 363, score 63.0, avg score 96.95
# episode 364, score 85.0, avg score 96.39
# episode 365, score 49.0, avg score 95.25
# episode 366, score 53.0, avg score 94.86
# episode 367, score 112.0, avg score 95.19
# episode 368, score 102.0, avg score 95.58
# episode 369, score 99.0, avg score 95.31
# episode 370, score 59.0, avg score 95.34
# episode 371, score 87.0, avg score 95.47
# episode 372, score 61.0, avg score 95.05
# episode 373, score 53.0, avg score 94.58
# episode 374, score 77.0, avg score 94.57
# episode 375, score 65.0, avg score 94.02
# episode 376, score 72.0, avg score 94.22
# episode 377, score 132.0, avg score 94.54
# episode 378, score 54.0, avg score 93.99
# episode 379, score 80.0, avg score 94.13
# episode 380, score 64.0, avg score 94.21
# episode 381, score 71.0, avg score 93.94
# episode 382, score 64.0, avg score 94.05
# episode 383, score 48.0, avg score 93.54
# episode 384, score 53.0, avg score 92.47
# episode 385, score 58.0, avg score 92.25
# episode 386, score 67.0, avg score 92.14
# episode 387, score 67.0, avg score 91.99
# episode 388, score 82.0, avg score 91.99
# episode 389, score 52.0, avg score 91.54
# episode 390, score 45.0, avg score 91.09
# episode 391, score 68.0, avg score 90.1
# episode 392, score 56.0, avg score 89.4
# episode 393, score 73.0, avg score 88.61
# episode 394, score 60.0, avg score 87.98
# episode 395, score 50.0, avg score 86.06
# episode 396, score 47.0, avg score 85.31
# episode 397, score 52.0, avg score 84.14
# episode 398, score 178.0, avg score 85.36
# episode 399, score 56.0, avg score 84.25
# episode 400, score 58.0, avg score 84.12
# episode 401, score 84.0, avg score 83.53
# episode 402, score 48.0, avg score 83.05
# episode 403, score 110.0, avg score 83.53
# episode 404, score 64.0, avg score 83.33
# episode 405, score 53.0, avg score 82.68
# episode 406, score 48.0, avg score 82.32
# episode 407, score 56.0, avg score 82.04
# episode 408, score 64.0, avg score 81.51
# episode 409, score 136.0, avg score 81.48
# episode 410, score 56.0, avg score 81.12
# episode 411, score 50.0, avg score 81.14
# episode 412, score 41.0, avg score 80.73
# episode 413, score 59.0, avg score 79.86
# episode 414, score 41.0, avg score 79.65
# episode 415, score 53.0, avg score 79.47
# episode 416, score 46.0, avg score 79.41
# episode 417, score 47.0, avg score 79.25
# episode 418, score 129.0, avg score 79.53
# episode 419, score 70.0, avg score 79.43
# episode 420, score 55.0, avg score 79.31
# episode 421, score 44.0, avg score 78.73
# episode 422, score 39.0, avg score 77.09
# episode 423, score 55.0, avg score 76.92
# episode 424, score 56.0, avg score 77.03
# episode 425, score 93.0, avg score 77.23
# episode 426, score 47.0, avg score 76.87
# episode 427, score 36.0, avg score 76.73
# episode 428, score 50.0, avg score 76.34
# episode 429, score 67.0, avg score 76.12
# episode 430, score 69.0, avg score 75.82
# episode 431, score 60.0, avg score 75.92
# episode 432, score 59.0, avg score 75.21
# episode 433, score 86.0, avg score 74.22
# episode 434, score 65.0, avg score 74.04
# episode 435, score 55.0, avg score 73.9
# episode 436, score 37.0, avg score 73.36
# episode 437, score 35.0, avg score 72.86
# episode 438, score 44.0, avg score 72.47
# episode 439, score 52.0, avg score 72.12
# episode 440, score 39.0, avg score 71.67
# episode 441, score 46.0, avg score 70.0
# episode 442, score 53.0, avg score 69.72
# episode 443, score 51.0, avg score 69.45
# episode 444, score 39.0, avg score 69.18
# episode 445, score 32.0, avg score 68.29
# episode 446, score 64.0, avg score 68.43
# episode 447, score 33.0, avg score 68.15
# episode 448, score 73.0, avg score 68.24
# episode 449, score 54.0, avg score 68.04
# episode 450, score 77.0, avg score 68.07
# episode 451, score 35.0, avg score 67.39
# episode 452, score 91.0, avg score 67.2
# episode 453, score 48.0, avg score 66.64
# episode 454, score 48.0, avg score 66.27
# episode 455, score 35.0, avg score 65.52
# episode 456, score 55.0, avg score 65.24
# episode 457, score 43.0, avg score 64.16
# episode 458, score 111.0, avg score 63.74
# episode 459, score 44.0, avg score 63.66
# episode 460, score 36.0, avg score 63.4
# episode 461, score 42.0, avg score 62.71
# episode 462, score 49.0, avg score 62.29
# episode 463, score 73.0, avg score 62.39
# episode 464, score 52.0, avg score 62.06
# episode 465, score 40.0, avg score 61.97
# episode 466, score 33.0, avg score 61.77
# episode 467, score 60.0, avg score 61.25
# episode 468, score 41.0, avg score 60.64
# episode 469, score 33.0, avg score 59.98
# episode 470, score 37.0, avg score 59.76
# episode 471, score 43.0, avg score 59.32
# episode 472, score 39.0, avg score 59.1
# episode 473, score 79.0, avg score 59.36
# episode 474, score 55.0, avg score 59.14
# episode 475, score 73.0, avg score 59.22
# episode 476, score 39.0, avg score 58.89
# episode 477, score 37.0, avg score 57.94
# episode 478, score 70.0, avg score 58.1
# episode 479, score 46.0, avg score 57.76
# episode 480, score 29.0, avg score 57.41
# episode 481, score 69.0, avg score 57.39
# episode 482, score 63.0, avg score 57.38
# episode 483, score 35.0, avg score 57.25
# episode 484, score 36.0, avg score 57.08
# episode 485, score 57.0, avg score 57.07
# episode 486, score 40.0, avg score 56.8
# episode 487, score 35.0, avg score 56.48
# episode 488, score 33.0, avg score 55.99
# episode 489, score 42.0, avg score 55.89
# episode 490, score 39.0, avg score 55.83
# episode 491, score 44.0, avg score 55.59
# episode 492, score 73.0, avg score 55.76
# episode 493, score 31.0, avg score 55.34
# episode 494, score 34.0, avg score 55.08
# episode 495, score 34.0, avg score 54.92
# episode 496, score 39.0, avg score 54.84
# episode 497, score 79.0, avg score 55.11
# episode 498, score 42.0, avg score 53.75
# episode 499, score 57.0, avg score 53.76
# episode 500, score 90.0, avg score 54.08
# episode 501, score 53.0, avg score 53.77
# episode 502, score 52.0, avg score 53.81
# episode 503, score 71.0, avg score 53.42
# episode 504, score 45.0, avg score 53.23
# episode 505, score 78.0, avg score 53.48
# episode 506, score 70.0, avg score 53.7
# episode 507, score 37.0, avg score 53.51
# episode 508, score 47.0, avg score 53.34
# episode 509, score 111.0, avg score 53.09
# episode 510, score 36.0, avg score 52.89
# episode 511, score 57.0, avg score 52.96
# episode 512, score 73.0, avg score 53.28
# episode 513, score 63.0, avg score 53.32
# episode 514, score 77.0, avg score 53.68
# episode 515, score 66.0, avg score 53.81
# episode 516, score 67.0, avg score 54.02
# episode 517, score 37.0, avg score 53.92
# episode 518, score 38.0, avg score 53.01
# episode 519, score 41.0, avg score 52.72
# episode 520, score 39.0, avg score 52.56
# episode 521, score 40.0, avg score 52.52
# episode 522, score 64.0, avg score 52.77
# episode 523, score 59.0, avg score 52.81
# episode 524, score 44.0, avg score 52.69
# episode 525, score 53.0, avg score 52.29
# episode 526, score 39.0, avg score 52.21
# episode 527, score 58.0, avg score 52.43
# episode 528, score 44.0, avg score 52.37
# episode 529, score 40.0, avg score 52.1
# episode 530, score 39.0, avg score 51.8
# episode 531, score 32.0, avg score 51.52
# episode 532, score 85.0, avg score 51.78
# episode 533, score 60.0, avg score 51.52
# episode 534, score 30.0, avg score 51.17
# episode 535, score 42.0, avg score 51.04
# episode 536, score 44.0, avg score 51.11
# episode 537, score 62.0, avg score 51.38
# episode 538, score 51.0, avg score 51.45
# episode 539, score 36.0, avg score 51.29
# episode 540, score 36.0, avg score 51.26
# episode 541, score 39.0, avg score 51.19
# episode 542, score 64.0, avg score 51.3
# episode 543, score 34.0, avg score 51.13
# episode 544, score 33.0, avg score 51.07
# episode 545, score 42.0, avg score 51.17
# episode 546, score 89.0, avg score 51.42
# episode 547, score 39.0, avg score 51.48
# episode 548, score 54.0, avg score 51.29
# episode 549, score 66.0, avg score 51.41
# episode 550, score 31.0, avg score 50.95
# episode 551, score 65.0, avg score 51.25
# episode 552, score 49.0, avg score 50.83
# episode 553, score 30.0, avg score 50.65
# episode 554, score 35.0, avg score 50.52
# episode 555, score 38.0, avg score 50.55
# episode 556, score 34.0, avg score 50.34
# episode 557, score 40.0, avg score 50.31
# episode 558, score 33.0, avg score 49.53
# episode 559, score 34.0, avg score 49.43
# episode 560, score 40.0, avg score 49.47
# episode 561, score 36.0, avg score 49.41
# episode 562, score 28.0, avg score 49.2
# episode 563, score 53.0, avg score 49.0
# episode 564, score 38.0, avg score 48.86
# episode 565, score 61.0, avg score 49.07
# episode 566, score 32.0, avg score 49.06
# episode 567, score 32.0, avg score 48.78
# episode 568, score 68.0, avg score 49.05
# episode 569, score 59.0, avg score 49.31
# episode 570, score 48.0, avg score 49.42
# episode 571, score 33.0, avg score 49.32
# episode 572, score 38.0, avg score 49.31
# episode 573, score 79.0, avg score 49.31
# episode 574, score 49.0, avg score 49.25
# episode 575, score 65.0, avg score 49.17
# episode 576, score 32.0, avg score 49.1
# episode 577, score 63.0, avg score 49.36
# episode 578, score 58.0, avg score 49.24
# episode 579, score 70.0, avg score 49.48
# episode 580, score 62.0, avg score 49.81
# episode 581, score 42.0, avg score 49.54
# episode 582, score 30.0, avg score 49.21
# episode 583, score 58.0, avg score 49.44
# episode 584, score 41.0, avg score 49.49
# episode 585, score 43.0, avg score 49.35
# episode 586, score 60.0, avg score 49.55
# episode 587, score 55.0, avg score 49.75
# episode 588, score 43.0, avg score 49.85
# episode 589, score 44.0, avg score 49.87
# episode 590, score 34.0, avg score 49.82
# episode 591, score 48.0, avg score 49.86
# episode 592, score 38.0, avg score 49.51
# episode 593, score 41.0, avg score 49.61
# episode 594, score 38.0, avg score 49.65
# episode 595, score 39.0, avg score 49.7
# episode 596, score 58.0, avg score 49.89
# episode 597, score 29.0, avg score 49.39
# episode 598, score 30.0, avg score 49.27
# episode 599, score 46.0, avg score 49.16
# episode 600, score 33.0, avg score 48.59
# episode 601, score 35.0, avg score 48.41
# episode 602, score 27.0, avg score 48.16
# episode 603, score 54.0, avg score 47.99
# episode 604, score 39.0, avg score 47.93
# episode 605, score 32.0, avg score 47.47
# episode 606, score 28.0, avg score 47.05
# episode 607, score 33.0, avg score 47.01
# episode 608, score 28.0, avg score 46.82
# episode 609, score 48.0, avg score 46.19
# episode 610, score 26.0, avg score 46.09
# episode 611, score 43.0, avg score 45.95
# episode 612, score 28.0, avg score 45.5
# episode 613, score 28.0, avg score 45.15
# episode 614, score 52.0, avg score 44.9
# episode 615, score 43.0, avg score 44.67
# episode 616, score 45.0, avg score 44.45
# episode 617, score 46.0, avg score 44.54
# episode 618, score 27.0, avg score 44.43
# episode 619, score 52.0, avg score 44.54
# episode 620, score 44.0, avg score 44.59
# episode 621, score 32.0, avg score 44.51
# episode 622, score 26.0, avg score 44.13
# episode 623, score 57.0, avg score 44.11
# episode 624, score 36.0, avg score 44.03
# episode 625, score 32.0, avg score 43.82
# episode 626, score 35.0, avg score 43.78
# episode 627, score 34.0, avg score 43.54
# episode 628, score 42.0, avg score 43.52
# episode 629, score 32.0, avg score 43.44
# episode 630, score 39.0, avg score 43.44
# episode 631, score 34.0, avg score 43.46
# episode 632, score 42.0, avg score 43.03
# episode 633, score 37.0, avg score 42.8
# episode 634, score 38.0, avg score 42.88
# episode 635, score 32.0, avg score 42.78
# episode 636, score 35.0, avg score 42.69
# episode 637, score 26.0, avg score 42.33
# episode 638, score 35.0, avg score 42.17
# episode 639, score 39.0, avg score 42.2
# episode 640, score 47.0, avg score 42.31
# episode 641, score 41.0, avg score 42.33
# episode 642, score 25.0, avg score 41.94
# episode 643, score 28.0, avg score 41.88
# episode 644, score 27.0, avg score 41.82
# episode 645, score 44.0, avg score 41.84
# episode 646, score 25.0, avg score 41.2
# episode 647, score 36.0, avg score 41.17
# episode 648, score 27.0, avg score 40.9
# episode 649, score 37.0, avg score 40.61
# episode 650, score 26.0, avg score 40.56
# episode 651, score 27.0, avg score 40.18
# episode 652, score 30.0, avg score 39.99
# episode 653, score 38.0, avg score 40.07
# episode 654, score 38.0, avg score 40.1
# episode 655, score 26.0, avg score 39.98
# episode 656, score 47.0, avg score 40.11
# episode 657, score 36.0, avg score 40.07
# episode 658, score 33.0, avg score 40.07
# episode 659, score 33.0, avg score 40.06
# episode 660, score 29.0, avg score 39.95
# episode 661, score 35.0, avg score 39.94
# episode 662, score 24.0, avg score 39.9
# episode 663, score 34.0, avg score 39.71
# episode 664, score 25.0, avg score 39.58
# episode 665, score 41.0, avg score 39.38
# episode 666, score 34.0, avg score 39.4
# episode 667, score 24.0, avg score 39.32
# episode 668, score 40.0, avg score 39.04
# episode 669, score 33.0, avg score 38.78
# episode 670, score 33.0, avg score 38.63
# episode 671, score 31.0, avg score 38.61
# episode 672, score 23.0, avg score 38.46
# episode 673, score 25.0, avg score 37.92
# episode 674, score 40.0, avg score 37.83
# episode 675, score 28.0, avg score 37.46
# episode 676, score 29.0, avg score 37.43
# episode 677, score 37.0, avg score 37.17
# episode 678, score 48.0, avg score 37.07
# episode 679, score 27.0, avg score 36.64
# episode 680, score 29.0, avg score 36.31
# episode 681, score 28.0, avg score 36.17
# episode 682, score 24.0, avg score 36.11
# episode 683, score 33.0, avg score 35.86
# episode 684, score 35.0, avg score 35.8
# episode 685, score 27.0, avg score 35.64
# episode 686, score 28.0, avg score 35.32
# episode 687, score 27.0, avg score 35.04
# episode 688, score 28.0, avg score 34.89
# episode 689, score 27.0, avg score 34.72
# episode 690, score 28.0, avg score 34.66
# episode 691, score 37.0, avg score 34.55
# episode 692, score 41.0, avg score 34.58
# episode 693, score 34.0, avg score 34.51
# episode 694, score 36.0, avg score 34.49
# episode 695, score 38.0, avg score 34.48
# episode 696, score 30.0, avg score 34.2
# episode 697, score 33.0, avg score 34.24
# episode 698, score 40.0, avg score 34.34
# episode 699, score 40.0, avg score 34.28
# episode 700, score 25.0, avg score 34.2
# episode 701, score 36.0, avg score 34.21
# episode 702, score 42.0, avg score 34.36
# episode 703, score 35.0, avg score 34.17
# episode 704, score 42.0, avg score 34.2
# episode 705, score 39.0, avg score 34.27
# episode 706, score 39.0, avg score 34.38
# episode 707, score 44.0, avg score 34.49
# episode 708, score 44.0, avg score 34.65
# episode 709, score 36.0, avg score 34.53
# episode 710, score 48.0, avg score 34.75
# episode 711, score 33.0, avg score 34.65
# episode 712, score 36.0, avg score 34.73
# episode 713, score 34.0, avg score 34.79
# episode 714, score 33.0, avg score 34.6
# episode 715, score 54.0, avg score 34.71
# episode 716, score 37.0, avg score 34.63
# episode 717, score 48.0, avg score 34.65
# episode 718, score 32.0, avg score 34.7
# episode 719, score 44.0, avg score 34.62
# episode 720, score 28.0, avg score 34.46
# episode 721, score 28.0, avg score 34.42
# episode 722, score 50.0, avg score 34.66
# episode 723, score 47.0, avg score 34.56
# episode 724, score 64.0, avg score 34.84
# episode 725, score 32.0, avg score 34.84
# episode 726, score 42.0, avg score 34.91
# episode 727, score 26.0, avg score 34.83
# episode 728, score 36.0, avg score 34.77
# episode 729, score 47.0, avg score 34.92
# episode 730, score 38.0, avg score 34.91
# episode 731, score 46.0, avg score 35.03
# episode 732, score 70.0, avg score 35.31
# episode 733, score 50.0, avg score 35.44
# episode 734, score 75.0, avg score 35.81
# episode 735, score 33.0, avg score 35.82
# episode 736, score 44.0, avg score 35.91
# episode 737, score 66.0, avg score 36.31
# episode 738, score 34.0, avg score 36.3
# episode 739, score 27.0, avg score 36.18
# episode 740, score 34.0, avg score 36.05
# episode 741, score 28.0, avg score 35.92
# episode 742, score 29.0, avg score 35.96
# episode 743, score 27.0, avg score 35.95
# episode 744, score 28.0, avg score 35.96
# episode 745, score 44.0, avg score 35.96
# episode 746, score 36.0, avg score 36.07
# episode 747, score 66.0, avg score 36.37
# episode 748, score 47.0, avg score 36.57
# episode 749, score 36.0, avg score 36.56
# episode 750, score 30.0, avg score 36.6
# episode 751, score 56.0, avg score 36.89
# episode 752, score 62.0, avg score 37.21
# episode 753, score 42.0, avg score 37.25
# episode 754, score 68.0, avg score 37.55
# episode 755, score 84.0, avg score 38.13
# episode 756, score 38.0, avg score 38.04
# episode 757, score 36.0, avg score 38.04
# episode 758, score 70.0, avg score 38.41
# episode 759, score 50.0, avg score 38.58
# episode 760, score 37.0, avg score 38.66
# episode 761, score 56.0, avg score 38.87
# episode 762, score 35.0, avg score 38.98
# episode 763, score 28.0, avg score 38.92
# episode 764, score 51.0, avg score 39.18
# episode 765, score 50.0, avg score 39.27
# episode 766, score 37.0, avg score 39.3
# episode 767, score 58.0, avg score 39.64
# episode 768, score 45.0, avg score 39.69
# episode 769, score 54.0, avg score 39.9
# episode 770, score 68.0, avg score 40.25
# episode 771, score 50.0, avg score 40.44
# episode 772, score 34.0, avg score 40.55
# episode 773, score 50.0, avg score 40.8
# episode 774, score 47.0, avg score 40.87
# episode 775, score 26.0, avg score 40.85
# episode 776, score 28.0, avg score 40.84
# episode 777, score 31.0, avg score 40.78
# episode 778, score 28.0, avg score 40.58
# episode 779, score 35.0, avg score 40.66
# episode 780, score 47.0, avg score 40.84
# episode 781, score 39.0, avg score 40.95
# episode 782, score 39.0, avg score 41.1
# episode 783, score 35.0, avg score 41.12
# episode 784, score 33.0, avg score 41.1
# episode 785, score 29.0, avg score 41.12
# episode 786, score 35.0, avg score 41.19
# episode 787, score 41.0, avg score 41.33
# episode 788, score 46.0, avg score 41.51
# episode 789, score 35.0, avg score 41.59
# episode 790, score 29.0, avg score 41.6
# episode 791, score 28.0, avg score 41.51
# episode 792, score 27.0, avg score 41.37
# episode 793, score 45.0, avg score 41.48
# episode 794, score 34.0, avg score 41.46
# episode 795, score 39.0, avg score 41.47
# episode 796, score 27.0, avg score 41.44
# episode 797, score 42.0, avg score 41.53
# episode 798, score 41.0, avg score 41.54
# episode 799, score 39.0, avg score 41.53
# episode 800, score 32.0, avg score 41.6
# episode 801, score 29.0, avg score 41.53
# episode 802, score 40.0, avg score 41.51
# episode 803, score 43.0, avg score 41.59
# episode 804, score 50.0, avg score 41.67
# episode 805, score 29.0, avg score 41.57
# episode 806, score 24.0, avg score 41.42
# episode 807, score 43.0, avg score 41.41
# episode 808, score 44.0, avg score 41.41
# episode 809, score 29.0, avg score 41.34
# episode 810, score 41.0, avg score 41.27
# episode 811, score 28.0, avg score 41.22
# episode 812, score 49.0, avg score 41.35
# episode 813, score 48.0, avg score 41.49
# episode 814, score 29.0, avg score 41.45
# episode 815, score 71.0, avg score 41.62
# episode 816, score 52.0, avg score 41.77
# episode 817, score 31.0, avg score 41.6
# episode 818, score 36.0, avg score 41.64
# episode 819, score 30.0, avg score 41.5
# episode 820, score 39.0, avg score 41.61
# episode 821, score 30.0, avg score 41.63
# episode 822, score 42.0, avg score 41.55
# episode 823, score 54.0, avg score 41.62
# episode 824, score 48.0, avg score 41.46
# episode 825, score 27.0, avg score 41.41
# episode 826, score 73.0, avg score 41.72
# episode 827, score 30.0, avg score 41.76
# episode 828, score 46.0, avg score 41.86
# episode 829, score 42.0, avg score 41.81
# episode 830, score 50.0, avg score 41.93
# episode 831, score 58.0, avg score 42.05
# episode 832, score 46.0, avg score 41.81
# episode 833, score 31.0, avg score 41.62
# episode 834, score 39.0, avg score 41.26
# episode 835, score 38.0, avg score 41.31
# episode 836, score 76.0, avg score 41.63
# episode 837, score 33.0, avg score 41.3
# episode 838, score 49.0, avg score 41.45
# episode 839, score 32.0, avg score 41.5
# episode 840, score 30.0, avg score 41.46
# episode 841, score 37.0, avg score 41.55
# episode 842, score 40.0, avg score 41.66
# episode 843, score 37.0, avg score 41.76
# episode 844, score 54.0, avg score 42.02
# episode 845, score 71.0, avg score 42.29
# episode 846, score 34.0, avg score 42.27
# episode 847, score 36.0, avg score 41.97
# episode 848, score 43.0, avg score 41.93
# episode 849, score 65.0, avg score 42.22
# episode 850, score 43.0, avg score 42.35
# episode 851, score 31.0, avg score 42.1
# episode 852, score 58.0, avg score 42.06
# episode 853, score 67.0, avg score 42.31
# episode 854, score 39.0, avg score 42.02
# episode 855, score 28.0, avg score 41.46
# episode 856, score 28.0, avg score 41.36
# episode 857, score 44.0, avg score 41.44
# episode 858, score 44.0, avg score 41.18
# episode 859, score 29.0, avg score 40.97
# episode 860, score 26.0, avg score 40.86
# episode 861, score 40.0, avg score 40.7
# episode 862, score 36.0, avg score 40.71
# episode 863, score 32.0, avg score 40.75
# episode 864, score 59.0, avg score 40.83
# episode 865, score 46.0, avg score 40.79
# episode 866, score 50.0, avg score 40.92
# episode 867, score 28.0, avg score 40.62
# episode 868, score 36.0, avg score 40.53
# episode 869, score 29.0, avg score 40.28
# episode 870, score 39.0, avg score 39.99
# episode 871, score 36.0, avg score 39.85
# episode 872, score 35.0, avg score 39.86
# episode 873, score 30.0, avg score 39.66
# episode 874, score 32.0, avg score 39.51
# episode 875, score 27.0, avg score 39.52
# episode 876, score 36.0, avg score 39.6
# episode 877, score 28.0, avg score 39.57
# episode 878, score 27.0, avg score 39.56
# episode 879, score 29.0, avg score 39.5
# episode 880, score 28.0, avg score 39.31
# episode 881, score 39.0, avg score 39.31
# episode 882, score 29.0, avg score 39.21
# episode 883, score 31.0, avg score 39.17
# episode 884, score 25.0, avg score 39.09
# episode 885, score 33.0, avg score 39.13
# episode 886, score 30.0, avg score 39.08
# episode 887, score 26.0, avg score 38.93
# episode 888, score 33.0, avg score 38.8
# episode 889, score 42.0, avg score 38.87
# episode 890, score 27.0, avg score 38.85
# episode 891, score 43.0, avg score 39.0
# episode 892, score 23.0, avg score 38.96
# episode 893, score 40.0, avg score 38.91
# episode 894, score 27.0, avg score 38.84
# episode 895, score 28.0, avg score 38.73
# episode 896, score 39.0, avg score 38.85
# episode 897, score 33.0, avg score 38.76
# episode 898, score 24.0, avg score 38.59
# episode 899, score 25.0, avg score 38.45
# episode 900, score 32.0, avg score 38.45
# episode 901, score 33.0, avg score 38.49
# episode 902, score 31.0, avg score 38.4
# episode 903, score 25.0, avg score 38.22
# episode 904, score 26.0, avg score 37.98
# episode 905, score 33.0, avg score 38.02
# episode 906, score 31.0, avg score 38.09
# episode 907, score 31.0, avg score 37.97
# episode 908, score 23.0, avg score 37.76
# episode 909, score 31.0, avg score 37.78
# episode 910, score 31.0, avg score 37.68
# episode 911, score 31.0, avg score 37.71
# episode 912, score 37.0, avg score 37.59
# episode 913, score 31.0, avg score 37.42
# episode 914, score 33.0, avg score 37.46
# episode 915, score 33.0, avg score 37.08
# episode 916, score 23.0, avg score 36.79
# episode 917, score 28.0, avg score 36.76
# episode 918, score 32.0, avg score 36.72
# episode 919, score 30.0, avg score 36.72
# episode 920, score 23.0, avg score 36.56
# episode 921, score 24.0, avg score 36.5
# episode 922, score 28.0, avg score 36.36
# episode 923, score 23.0, avg score 36.05
# episode 924, score 27.0, avg score 35.84
# episode 925, score 28.0, avg score 35.85
# episode 926, score 19.0, avg score 35.31
# episode 927, score 20.0, avg score 35.21
# episode 928, score 22.0, avg score 34.97
# episode 929, score 35.0, avg score 34.9
# episode 930, score 24.0, avg score 34.64
# episode 931, score 22.0, avg score 34.28
# episode 932, score 27.0, avg score 34.09
# episode 933, score 34.0, avg score 34.12
# episode 934, score 23.0, avg score 33.96
# episode 935, score 21.0, avg score 33.79
# episode 936, score 23.0, avg score 33.26
# episode 937, score 23.0, avg score 33.16
# episode 938, score 29.0, avg score 32.96
# episode 939, score 19.0, avg score 32.83
# episode 940, score 20.0, avg score 32.73
# episode 941, score 18.0, avg score 32.54
# episode 942, score 21.0, avg score 32.35
# episode 943, score 21.0, avg score 32.19
# episode 944, score 20.0, avg score 31.85
# episode 945, score 25.0, avg score 31.39
# episode 946, score 32.0, avg score 31.37
# episode 947, score 16.0, avg score 31.17
# episode 948, score 18.0, avg score 30.92
# episode 949, score 23.0, avg score 30.5
# episode 950, score 27.0, avg score 30.34
# episode 951, score 26.0, avg score 30.29
# episode 952, score 25.0, avg score 29.96
# episode 953, score 22.0, avg score 29.51
# episode 954, score 20.0, avg score 29.32
# episode 955, score 21.0, avg score 29.25
# episode 956, score 23.0, avg score 29.2
# episode 957, score 18.0, avg score 28.94
# episode 958, score 18.0, avg score 28.68
# episode 959, score 16.0, avg score 28.55
# episode 960, score 18.0, avg score 28.47
# episode 961, score 24.0, avg score 28.31
# episode 962, score 21.0, avg score 28.16
# episode 963, score 17.0, avg score 28.01
# episode 964, score 30.0, avg score 27.72
# episode 965, score 21.0, avg score 27.47
# episode 966, score 25.0, avg score 27.22
# episode 967, score 22.0, avg score 27.16
# episode 968, score 22.0, avg score 27.02
# episode 969, score 20.0, avg score 26.93
# episode 970, score 19.0, avg score 26.73
# episode 971, score 29.0, avg score 26.66
# episode 972, score 18.0, avg score 26.49
# episode 973, score 19.0, avg score 26.38
# episode 974, score 24.0, avg score 26.3
# episode 975, score 17.0, avg score 26.2
# episode 976, score 23.0, avg score 26.07
# episode 977, score 18.0, avg score 25.97
# episode 978, score 22.0, avg score 25.92
# episode 979, score 18.0, avg score 25.81
# episode 980, score 21.0, avg score 25.74
# episode 981, score 18.0, avg score 25.53
# episode 982, score 23.0, avg score 25.47
# episode 983, score 20.0, avg score 25.36
# episode 984, score 23.0, avg score 25.34
# episode 985, score 17.0, avg score 25.18
# episode 986, score 16.0, avg score 25.04
# episode 987, score 25.0, avg score 25.03
# episode 988, score 15.0, avg score 24.85
# episode 989, score 20.0, avg score 24.63
# episode 990, score 22.0, avg score 24.58
# episode 991, score 16.0, avg score 24.31
# episode 992, score 23.0, avg score 24.31
# episode 993, score 23.0, avg score 24.14
# episode 994, score 17.0, avg score 24.04
# episode 995, score 15.0, avg score 23.91
# episode 996, score 22.0, avg score 23.74
# episode 997, score 22.0, avg score 23.63
# episode 998, score 15.0, avg score 23.54
# episode 999, score 18.0, avg score 23.47
